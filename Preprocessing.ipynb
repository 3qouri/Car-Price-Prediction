# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import os

# %%
data=pd.read_csv('car_price_prediction.csv')

# %%
# remove outliers
numric_cols = data.select_dtypes(include=['int64', 'float64']).columns
outliers = {}
for col in numric_cols:
    Q1 = data[col].quantile(0.25)
    Q3 = data[col].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    outliers[col] = data[(data[col] < lower_bound) | (data[col] > upper_bound)]
outliers
# Out:
# {'ID':              ID  Price  Levy   Manufacturer           Model  Prod. year  \
#  1      44731507  16621  1018      CHEVROLET         Equinox        2011
#  15     45465200    549  1079         TOYOTA             CHR        2018
#  21     45168471  20698   586         TOYOTA           Prius        2012
#  30     44944581  15681  1288  MERCEDES-BENZ            Vito        2007
#  34     45542380  24462     -           JEEP  Grand Cherokee        2007
#  ...         ...    ...   ...            ...             ...         ...
#  19176  45511664  14113   531        HYUNDAI        Veloster        2012
#  19192  45172859  14113     -          SCION              xD        2010
#  19208  45433278  34811   779         TOYOTA           RAV 4        2013
#  19223  44571028   8781     -          DODGE         Caliber        2008
#  19229  39977395     50     -         TOYOTA           Prius        2008
#
#            Category Leather interior       Fuel type Engine volume    Mileage  \
#  1             Jeep               No          Petrol             3  192000 km
#  15            Jeep              Yes          Petrol             2   74146 km
#  21           Sedan              Yes  Plug-in Hybrid           1.8  187000 km
#  30     Goods wagon               No          Diesel     2.0 Turbo  180000 km
#  34            Jeep              Yes          Diesel     3.0 Turbo  250000 km
#  ...            ...              ...             ...           ...        ...
#  19176    Hatchback               No          Petrol           1.6  130000 km
#  19192    Hatchback               No          Petrol           1.8  203000 km
#  19208         Jeep               No          Petrol           2.5  121400 km
#  19223    Hatchback               No          Petrol           2.4       0 km
#  19229    Hatchback               No          Hybrid           1.5  150000 km
#
#         Cylinders Gear box type Drive wheels   Doors       Wheel   Color  \
#  1            6.0     Tiptronic          4x4  04-May  Left wheel   Black
#  15           4.0     Automatic        Front  04-May  Left wheel   White
#  21           4.0     Automatic        Front  04-May  Left wheel   White
#  30           6.0        Manual         Rear  04-May  Left wheel   White
#  34           6.0     Tiptronic          4x4  04-May  Left wheel   Black
#  ...          ...           ...          ...     ...         ...     ...
#  19176        4.0        Manual        Front  04-May  Left wheel    Blue
#  19192        4.0     Automatic        Front  04-May  Left wheel   White
#  19208        4.0     Tiptronic        Front  04-May  Left wheel    Grey
#  19223        4.0     Automatic        Front  04-May  Left wheel    Blue
#  19229        4.0     Automatic        Front  04-May  Left wheel  Silver
#
#         Airbags
#  1            8
#  15          12
#  21          12
#  30           4
#  34          10
#  ...        ...
#  19176       12
#  19192        8
#  19208        6
#  19223        4
#  19229        6
#
#  [2531 rows x 18 columns],
#  'Price':              ID  Price  Levy   Manufacturer           Model  Prod. year  \
#  14     45732604  59464   891        HYUNDAI        Santa FE        2016
#  36     45369569  51746  1077         TOYOTA     CHR Limited        2019
#  47     45732544  55390  1017        HYUNDAI        Santa FE        2017
#  56     44316016  87112     -  MERCEDES-BENZ         GLA 250        2019
#  73     45732043  53154   891        HYUNDAI        Santa FE        2016
#  ...         ...    ...   ...            ...             ...         ...
#  19144  45733642  56814  1017        HYUNDAI          Sonata        2017
#  19161  45677230  64290     -          LEXUS  RX 450 F SPORT        2012
#  19180  45803164  63886  1076        HYUNDAI          Sonata        2020
#  19188  45571892  61154   579         TOYOTA           RAV 4        2017
#  19211  45802856  50037   891        HYUNDAI        Santa FE        2016
#
#        Category Leather interior Fuel type Engine volume    Mileage  Cylinders  \
#  14        Jeep              Yes    Diesel             2   76000 km        4.0
#  36        Jeep               No    Petrol             2   10200 km        4.0
#  47        Jeep              Yes    Diesel             2  100734 km        4.0
#  56        Jeep              Yes    Petrol     2.0 Turbo    5323 km        4.0
#  73        Jeep              Yes    Diesel             2   84506 km        4.0
#  ...        ...              ...       ...           ...        ...        ...
#  19144    Sedan              Yes    Petrol             2   67365 km        4.0
#  19161     Jeep              Yes    Hybrid           3.5   97000 km        6.0
#  19180    Sedan              Yes       LPG             2    5305 km        4.0
#  19188     Jeep               No    Hybrid           2.5   71234 km        4.0
#  19211     Jeep              Yes    Diesel             2  121902 km        4.0
#
#        Gear box type Drive wheels   Doors       Wheel   Color  Airbags
#  14        Automatic        Front  04-May  Left wheel   White        4
#  36        Tiptronic        Front  04-May  Left wheel     Red       12
#  47        Automatic        Front  04-May  Left wheel   Black        4
#  56        Tiptronic          4x4  04-May  Left wheel    Grey        0
#  73        Automatic        Front  04-May  Left wheel  Silver        4
#  ...             ...          ...     ...         ...     ...      ...
#  19144     Automatic        Front  04-May  Left wheel   Black        4
#  19161      Variator          4x4  04-May  Left wheel   Black       12
#  19180     Automatic        Front  04-May  Left wheel  Silver        4
#  19188     Tiptronic          4x4  04-May  Left wheel   White       12
#  19211     Automatic        Front  04-May  Left wheel   Black        4
#
#  [1073 rows x 18 columns],
#  'Prod. year':              ID  Price Levy   Manufacturer      Model  Prod. year  \
#  11     45814819   8781    -           FORD    Transit        1999
#  12     45815568   3000    -           OPEL     Vectra        1997
#  24     45813492   4704    -           OPEL     Vectra        1995
#  83     45765301   8154    -          HONDA       Cr-v        1998
#  91     45733554   2822    -            BMW  520 Vanos        1995
#  ...         ...    ...  ...            ...        ...         ...
#  19187  45772786   7213    -            BMW        525        1998
#  19193  45793905   7527    -     MITSUBISHI  Pajero IO        1999
#  19194  45715218    500    -           FORD    Transit        1998
#  19199  45761409   3763    -  MERCEDES-BENZ      C 180        1995
#  19232  45798355   8467    -  MERCEDES-BENZ    CLK 200        1999
#
#            Category Leather interior Fuel type Engine volume        Mileage  \
#  11        Microbus               No       CNG             4           0 km
#  12     Goods wagon               No       CNG           1.6      350000 km
#  24           Sedan               No    Petrol           1.8           0 km
#  83            Jeep               No    Petrol             2           0 km
#  91           Sedan              Yes    Petrol             2      350000 km
#  ...            ...              ...       ...           ...            ...
#  19187        Sedan               No       CNG           2.5      212000 km
#  19193         Jeep               No    Petrol           1.8      245000 km
#  19194     Microbus               No    Diesel           2.5      760000 km
#  19199        Sedan               No    Petrol           1.8  1111111111 km
#  19232        Coupe              Yes       CNG     2.0 Turbo      300000 km
#
#         Cylinders Gear box type Drive wheels   Doors             Wheel   Color  \
#  11           8.0        Manual         Rear  02-Mar        Left wheel    Blue
#  12           4.0        Manual        Front  04-May        Left wheel   White
#  24           4.0     Automatic        Front  04-May        Left wheel   Green
#  83           4.0     Automatic          4x4  04-May  Right-hand drive   White
#  91           6.0        Manual         Rear  04-May        Left wheel    Blue
#  ...          ...           ...          ...     ...               ...     ...
#  19187        6.0        Manual         Rear  04-May        Left wheel  Silver
#  19193        4.0     Automatic          4x4  04-May        Left wheel   Green
#  19194        4.0        Manual         Rear  04-May        Left wheel   White
#  19199        5.0        Manual         Rear  04-May  Right-hand drive   Green
#  19232        4.0        Manual         Rear  02-Mar        Left wheel  Silver
#
#         Airbags
#  11           0
#  12           4
#  24           4
#  83           2
#  91           2
#  ...        ...
#  19187        6
#  19193        6
#  19194        2
#  19199        2
#  19232        5
#
#  [982 rows x 18 columns],
#  'Cylinders':              ID  Price  Levy   Manufacturer    Model  Prod. year  Category  \
#  0      45654403  13328  1399          LEXUS   RX 450        2010      Jeep
#  1      44731507  16621  1018      CHEVROLET  Equinox        2011      Jeep
#  9      45756839  26657     -          LEXUS   RX 350        2007      Jeep
#  10     45621750    941  1053  MERCEDES-BENZ    E 350        2014     Sedan
#  11     45814819   8781     -           FORD  Transit        1999  Microbus
#  ...         ...    ...   ...            ...      ...         ...       ...
#  19221  45776906  15681     -     VOLKSWAGEN    Jetta        2013     Sedan
#  19226  45796788   7840     -         NISSAN  Skyline        2003     Sedan
#  19227  45769427  29793  1053  MERCEDES-BENZ    E 350        2014     Sedan
#  19228  45773726    706  1850  MERCEDES-BENZ    E 350        2008     Sedan
#  19231  45772306   5802  1055  MERCEDES-BENZ    E 350        2013     Sedan
#
#        Leather interior Fuel type Engine volume    Mileage  Cylinders  \
#  0                  Yes    Hybrid           3.5  186005 km        6.0
#  1                   No    Petrol             3  192000 km        6.0
#  9                  Yes    Petrol           3.5  128500 km        6.0
#  10                 Yes    Diesel           3.5  184467 km        6.0
#  11                  No       CNG             4       0 km        8.0
#  ...                ...       ...           ...        ...        ...
#  19221              Yes    Petrol           2.5   81200 km        5.0
#  19226              Yes    Petrol             3  220000 km        6.0
#  19227              Yes    Diesel           3.5  219030 km        6.0
#  19228              Yes    Diesel           3.5  122874 km        6.0
#  19231              Yes    Diesel           3.5  107800 km        6.0
#
#        Gear box type Drive wheels   Doors             Wheel   Color  Airbags
#  0         Automatic          4x4  04-May        Left wheel  Silver       12
#  1         Tiptronic          4x4  04-May        Left wheel   Black        8
#  9         Automatic          4x4  04-May        Left wheel  Silver       12
#  10        Automatic         Rear  04-May        Left wheel   White       12
#  11           Manual         Rear  02-Mar        Left wheel    Blue        0
#  ...             ...          ...     ...               ...     ...      ...
#  19221        Manual        Front  04-May        Left wheel  Silver       12
#  19226     Tiptronic         Rear  04-May  Right-hand drive   White        0
#  19227     Automatic          4x4  04-May        Left wheel   Black       12
#  19228     Automatic         Rear  04-May        Left wheel   Black       12
#  19231     Automatic         Rear  04-May        Left wheel    Grey       12
#
#  [4870 rows x 18 columns],
#  'Airbags': Empty DataFrame
#  Columns: [ID, Price, Levy, Manufacturer, Model, Prod. year, Category, Leather interior, Fuel type, Engine volume, Mileage, Cylinders, Gear box type, Drive wheels, Doors, Wheel, Color, Airbags]
#  Index: []}
